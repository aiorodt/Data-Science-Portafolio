# %% [markdown]
# ## 🔹 Clase 16 – Mini Proyecto Integrador I
# ### 🎯 Objetivo
# Aplicar variables, operadores, condicionales, bucles y estructuras de datos en un proyecto sencillo pero completo.
#
# ### 💡 Propuesta de mini proyectos:
#
# #### 1. Sistema de gestión de tareas (To-Do List en consola)
#
# - Guardar tareas en una lista o diccionario.
#
# - Poder añadir, marcar como completada, eliminar y mostrar tareas.
#
# - Usar bucles para menús interactivos.
#
# - Usar condicionales para las opciones del usuario.
#
# #### 2. Juego del Adivina el Número
#
# - Generar un número aleatorio.
#
# - Usar bucles while para dar intentos al jugador.
#
# - Condicionales para decir si el número es mayor o menor.
#
# - Contador de intentos.
#
# #### 3. Sistema de calificaciones
#
# - Guardar las notas de varios estudiantes en un diccionario.
#
# - Calcular promedio, nota mayor y menor.
#
# - Mostrar estadísticas usando estructuras de datos.

# %%
# 1. Sistema de gestión de tareas (To-Do List en consola)

# Guardar tareas en una lista o diccionario.
# Poder añadir, marcar como completada, eliminar y mostrar tareas.
# Usar bucles para menús interactivos.
# Usar condicionales para las opciones del usuario.

# Creo variables de tareas pendiente en forma de lista
tarea_pendiente = [] # lista vacia de tarea

# Creo Variable de tareas completadas
tarea_completada = []

#Creo Bucle While para gestionar las opciones 
while True:
    print('Bienvenido al sistema de gestion de tareas')
    print('Opcion 0 Tareas Pendiente')
    print('Opcion 1 Agregar Tarea')
    print('Opcion 2 Eliminar Tarea')
    print('Opcion 3 Tareas Completada')
    print('Opcion 4 Mostrar Tarea')
    print('Opcion 5 Salir')

    # manejo de errores de la variable opcion 
    try: 
        opcion = int(input('Seleccione una opcion entre 0 al 5'))
    except ValueError:
        print('❌ Error debe ingresar unicamente numeros enteros entre 0 y 5')
        continue
    if (0 > opcion) or (opcion > 5):
        print('❌Error debe ingresar unicamente valores entre 0 y 5') 
        continue
    
    # Tareas pendiente
    elif opcion == 0:
        if not tarea_pendiente:
            print('No tiene Tarea pendientes')
        else:
            print('Lista de Tareas Pendientes')
            for n,tarea in enumerate(tarea_pendiente):
                print(f'{n} ➡️ {tarea}')

    # Agregar Tarea a la Lista 
    elif opcion == 1:
        tarea_pendiente.append(input('Ingrese la tarea pendiente').lower())
        print(f'Tarea agregada como pendiente: {tarea_pendiente}')
    
    # Eliminar Tarea 
    elif opcion == 2:
        # tarea eliminada
        tarea_eliminada = input('Ingrese tarea a eliminar')
        
        #manejo de Errores
        try: 
            tarea_pendiente.remove(tarea_eliminada)
            print(f'Actualizando lista de tarea despues de la eliminacion {tarea_pendiente}')
        except ValueError:
            print(f'❌ Error La tarea {tarea_eliminada}, no existe en la lista de tarea pendiente')
            continue
        
    # Tarea Completada
    elif opcion == 3:
        # tarea completada
        completa = input('Ingrese la tarea completada')
        try:
            tarea_pendiente.remove(completa)
            print(f'Usted a cumplido con exito la tarea pendiente {completa}👍')
            tarea_completada.append(completa)
        except:
            print(f'❌ Error La tarea {completa}, no existe en la lista de tarea pendiente')
            continue
    
    # mostrar tareas 
    elif opcion == 4:
        
        if not tarea_pendiente:
            print('No Existe Tarea Completada ni Pendiente🔎')
            continue
        # tareas pendientes
        print(f'\nLista de Tareas Pendientes')
        for n1, tarea1 in enumerate(tarea_pendiente):
            print(f'{n1} ➡️ {tarea1}')
        
        # tareas completas
        print(f'\nLista de Tareas Completada')
        for n2, tarea2 in enumerate(tarea_completada):
            print(f'{n2} ➡️ {tarea2}')

    # Cierre del programa
    else:
        print('👋 Hasta Luego, Nos Vemos Pronto')
        break
# Out:
# Bienvenido al sistema de gestion de tareas
# Opcion 0 Tareas Pendientes
# Opcion 1 Agregar Tarea
# Opcion 2 Eliminar Tarea
# Opcion 3 Tareas Completada
# Opcion 4 Mostrar Tarea
# Opcion 5 Salir
# Tarea agregada como pendiente: ['ir al gym']
# Tarea agregada como pendiente: ['ir al gym', 'metro']
# Tarea agregada como pendiente: ['ir al gym', 'metro', 'zelda']
# Tarea agregada como pendiente: ['ir al gym', 'metro', 'zelda', 'megaman']
# Tarea agregada como pendiente: ['ir al gym', 'metro', 'zelda', 'megaman', 'rapidez']
# Usted a cumplido con exito la tarea pendiente metro
#
# Lista de Tareas Pendientes
# 0 ➡️ ir al gym
# 1 ➡️ zelda
# 2 ➡️ megaman
# 3 ➡️ rapidez
#
# Lista de Tareas Completada
# 0 ➡️ metro
# ❌ Error La tarea zel, no existe en la lista de tarea pendiente
# ❌ Error debe ingresar unicamente numeros enteros entre 0 y 5
# Actualizando lista de tarea despues de la eliminacion ['ir al gym', 'megaman', 'rapidez']
# Hasta Luego, Nos Vemos Pronto

# %%
# #### 2. Juego del Adivina el Número
#- Generar un número aleatorio
#- Usar bucles while para dar intentos al jugador.
#- Condicionales para decir si el número es mayor o menor.
#- Contador de intentos.

# Importamos el modulo random para generar el numero al azar 
import random 

# creo el intervalo de numeros adivinar 
n_min  = 0
n_max  = 99

# Creo el numero al azar para adivinar
numero = random.randint(n_min,n_max)

# creo la variable intento 
intento = 0

# Bloque While para iniciar el juego

print('Bienvenido al Juego de la adivinanza ')
while True:
    intento +=1 # indica el numero de intento

    # Creo Variable numero_adivinado y manejo de errores.
    try:
        numero_advinado = int(input('⁉️Ingrese un numero del 0 al 99⁉️'))
    except ValueError:
        print('❌❌ Error debe ingresar unicamente numeros enteros')
        continue

    # Manejor de numero negativos y muy altos 
    if (0 > numero_advinado) or (numero_advinado > 99):
        print('🛑Error Ingrese unicamente numeros de 0 al 100')
        continue

    # condiciones de numero mayor y menor
    elif numero_advinado > numero:
        print('El Numero ingresado es muy alto ⬆️. Ingrese uno menor ⬇️')
    
    elif numero_advinado < numero:
        print('El Numero ingresado es muy bajo ⬇️. Ingrese uno mayor ⬆️')
    
    # Condicion de ganadora
    else:
        print(f'Felicidades 🎉🎉🎉🎉🎉\nIntentos realizados {intento}')
        break
# Out:
# Bienvenido al Juego de la adivinanza
# El Numero ingresado es muy bajo ⬇️. Ingrese uno mayor ⬆️
# El Numero ingresado es muy bajo ⬇️. Ingrese uno mayor ⬆️
# El Numero ingresado es muy alto ⬆️. Ingrese uno menor ⬇️
# El Numero ingresado es muy alto ⬆️. Ingrese uno menor ⬇️
# El Numero ingresado es muy alto ⬆️. Ingrese uno menor ⬇️
# El Numero ingresado es muy alto ⬆️. Ingrese uno menor ⬇️
# Felicidades 🎉🎉🎉🎉🎉
# Intentos realizados 7

# %%
# 3. Sistema de calificaciones
#- Guardar las notas de varios estudiantes en un diccionario.
#- Calcular promedio, nota mayor y menor.
#- Mostrar estadísticas usando estructuras de datos.

import pandas as pd
from IPython.display import display


# Creo dicionario de estudiantes - notas 
lista_estudiante_nota = {}
# sistema de calificacion de notas 


    # Instruciones 
print('Ingresando al Sistema de Calificacion de Notas🗒️')
print('Opcion 1 Ingrese, Nombre y Calificacion del Estudiante 🧑‍🎓')
print('Opcion 2 Eliminar Estudiante de la lista🗒️❌')
print('Opcion 3 Estadistica de Calificaciones🎰')
print('Opcion 4 Tabla de Nota📚')
print("Opcion Seleccione cualquieero otro numero para Salir del Sistema👋")

# creando bucle While
while True:

    # Manejo de error opcion
    try:
        opcion = int(input('Elige Una Opcion'))
    except ValueError:
        print('❌Error ingrese unicamente valores enteros')
        continue
    
    # condicion de opcion 
    if (1 > opcion ) or (opcion > 5):
        print('❌Error ingrese unicamente valores entre 1 y 5')

    # opcion agregar estudiante y nota
    if opcion == 1:
        nombre_estudiante = input('Ingrese el nombre del estudiante➕').strip().capitalize()
        
        #manejo de nota del estudiante del 1 al 10 
        try:
            nota = int(input('🎰Ingrese una nota del 1 al 10'))
        except ValueError:
            print('❌Error ingrese unicamente numeros enteros')
            continue
        if (1 <= nota) and (nota <=10):
            # agrego nota a la lista
            lista_estudiante_nota[nombre_estudiante] = nota
            print(f'El estudiante agregado en la lista es: {nombre_estudiante} ➡️ Nota {nota}')
        else:
            print('❌Error ingrese un numero entre 1 y 10')
    
    # Condicion de eliminar estudiante 
    elif opcion == 2:
        nombre_eliminar = input('Ingrese el nombre del estudiante a Eliminar').strip().capitalize()

        if nombre_eliminar in lista_estudiante_nota:
            del lista_estudiante_nota[nombre_eliminar]
            print(f'🆑Estudiante eliminado: {nombre_eliminar}')
        else:
            print('🛑 El estudiante no se Encuentra en la lista')
    
    # Visualizacion de estadisticas
    elif opcion == 3:
        if not lista_estudiante_nota:
            print('❌No hay estudiante en la lista🗒️')
        else:
            print('Estadistica de Los estudiante')
            # nota max,min y media
            max_nota = max(lista_estudiante_nota.values())
            min_nota = min(lista_estudiante_nota.values())
            media_nota = sum(lista_estudiante_nota.values())/len(lista_estudiante_nota)
            
            # Visualizacion de datos estadistico
            date_nota = {
                'MAXIMA NOTA':max_nota,
                'MINIMA NOTA':min_nota,
                'MEDIA':media_nota
            }
            # creo un DataFrame 
            df_nota = pd.DataFrame([date_nota],index=['RESULTADOS'])

            #visualizacion de parametros estadisticos 
            display(df_nota)

    # Resumen de notas de los estudiantes 
    elif opcion == 4:
        if not lista_estudiante_nota :
            print('❌No hay estudiante en la lista🗒️')
        else:
            df_estudiante = pd.DataFrame([lista_estudiante_nota],index=['NOTA'])
            display(df_estudiante)
    elif opcion == 5:
        print('👋Saliendo del sistema')
        print('Hasta Pronto👋')
        break
# Out:
# Ingresando al Sistema de Calificacion de Notas🗒️
# Opcion 1 Ingrese, Nombre y Calificacion del Estudiante 🧑‍🎓
# Opcion 2 Eliminar Estudiante de la lista🗒️❌
# Opcion 3 Estadistica de Calificaciones🎰
# Opcion 4 Tabla de Nota📚
# Opcion Seleccione cualquieero otro numero para Salir del Sistema👋
# ❌Error ingrese unicamente valores entre 1 y 5
# ❌Error ingrese unicamente valores entre 1 y 5
# ❌Error ingrese unicamente valores entre 1 y 5
# ❌Error ingrese unicamente valores enteros
# ❌Error ingrese unicamente valores entre 1 y 5
# ❌Error ingrese unicamente valores entre 1 y 5
# 👋Saliendo del sistema
# Hasta Pronto👋
